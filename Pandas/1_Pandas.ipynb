# %% [markdown]
# Pandas importing and Exporting

# %%
import pandas as pd

# %%
df = pd.read_csv("car-sales.csv", header=0)

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df.to_csv("ModifiedCarSales.csv", index=False)

# %% [markdown]
# ## Describe Data

# %%
# Attibute
df.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
column_names = df.columns

# %%
column_names
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
df['Doors'].mean()
# Out:
# 4.0

# %%
df['Doors'].sum()
# Out:
# 40

# %%
len(df)
# Out:
# 10

# %% [markdown]
# ## Viewing and selecting data

# %%
df.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
df.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df.loc[1, 'Make']
# Out:
# 'Honda'

# %%
df.loc[8, 'Odometer (KM)']
# Out:
# 60000

# %%
animals = pd.Series(['Cat', 'Dog', 'Bird', 'Panda', 'Snake'], index = [0, 3, 9, 8, 3])

# %%
animals.loc[3]
# Out:
# 3      Dog
# 3    Snake
# dtype: object

# %%
df.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
df.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals.iloc[3]
# Out:
# 'Panda'

# %%
df.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
df["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
df.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
df[df["Make"]=='Honda']
# Out:
#     Make Colour  Odometer (KM)  Doors      Price
# 1  Honda    Red          87899      4  $5,000.00
# 6  Honda   Blue          45698      4  $7,500.00
# 7  Honda   Blue          54738      4  $7,000.00

# %%
df[df["Doors"]>4]
# Out:
#   Make Colour  Odometer (KM)  Doors       Price
# 3  BMW  Black          11179      5  $22,000.00

# %%
df.Doors
# Out:
# 0    4
# 1    4
# 2    3
# 3    5
# 4    4
# 5    4
# 6    4
# 7    4
# 8    4
# 9    4
# Name: Doors, dtype: int64

# %%
df[(df["Doors"]<=4)&(df["Make"]=="Toyota")]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
df[df.Make=='Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
df[(df["Odometer (KM)"]>100000)&(df.Make=='Toyota')]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00

# %%
df["Price"].str.replace(r'[\$\,\.]','', regex=True)
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: object

# %%
df
# Out:
#         0
# 2    Ford
# 4    Ford
# 2  Toyota
# 2    Ford
# 4  Toyota

# %%
pd.crosstab(df.,df.Price)
# Out:
# Make        BMW  Honda  Nissan  Toyota
# Price
# $22,000.00    1      0       0       0
# $3,500.00     0      0       1       0
# $4,000.00     0      0       0       1
# $4,500.00     0      0       0       1
# $5,000.00     0      1       0       0
# $6,250.00     0      0       0       1
# $7,000.00     0      1       0       1
# $7,500.00     0      1       0       0
# $9,700.00     0      0       1       0

# %%
pd.crosstab(df["Colour"], df["Odometer (KM)"])
# Out:
# Odometer (KM)  11179   31600   32549   45698   54738   60000   87899   99213   \
# Colour
# Black               1       0       0       0       0       0       0       0
# Blue                0       0       1       1       1       0       0       0
# Green               0       0       0       0       0       0       0       1
# Red                 0       0       0       0       0       0       1       0
# White               0       1       0       0       0       1       0       0
#
# Odometer (KM)  150043  213095
# Colour
# Black               0       0
# Blue                0       0
# Green               0       0
# Red                 0       0
# White               1       1

# %%
df = pd.read_csv("car-sales.csv", header=0)

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
df.groupby(["Make"]).sum(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW             11179      5
# Honda          188335     12
# Nissan         244695      8
# Toyota         341805     15

# %%
df["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
df["Price"].dtype
# Out:
# dtype('int64')

# %%
df["Price"] = df["Price"].str.replace(r'[\$\,\.]', '', regex=True)

# %%
df["Price"]
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: object

# %%
df["Price"] = pd.to_numeric(df["Price"])

# %%
df["Price"].plot()
# Out:
# <Axes: >

# %%
df["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
df['Price'].dtype
# Out:
# dtype('int64')

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
df['Make'] = df["Make"].str.lower()

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
df["Colour"].str.upper()
# Out:
# 0    WHITE
# 1      RED
# 2     BLUE
# 3    BLACK
# 4    WHITE
# 5    GREEN
# 6     BLUE
# 7     BLUE
# 8    WHITE
# 9    WHITE
# Name: Colour, dtype: object

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %% [markdown]
# # We have to assign upper() function to the data

# %%
df["Colour"] = df["Colour"].str.upper()

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  WHITE         150043      4   400000
# 1   honda    RED          87899      4   500000
# 2  toyota   BLUE          32549      3   700000
# 3     bmw  BLACK          11179      5  2200000
# 4  nissan  WHITE         213095      4   350000
# 5  toyota  GREEN          99213      4   450000
# 6   honda   BLUE          45698      4   750000
# 7   honda   BLUE          54738      4   700000
# 8  toyota  WHITE          60000      4   625000
# 9  nissan  WHITE          31600      4   970000

# %%
df = pd.read_csv('car-sales-missing-data.csv', header=0)

# %%
df
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
i = df["Odometer"].mean()

# %%
df["Odometer"].fillna(i)
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
for i in df.index:
    if df.loc[i, "Odometer"]>70000:
        df.loc[i, "Odometer"]=85000

# %%
df["Odometer"]
# Out:
# 3    11179.0
# 8    60000.0
# 9    31600.0
# Name: Odometer, dtype: float64

# %%
df
# Out:
#      Make Colour  Odometer  Doors    Price
# 3     BMW  Black   11179.0    5.0  $22,000
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
df
# Out:
#      Make Colour  Odometer  Doors    Price
# 3     BMW  Black   11179.0    5.0  $22,000
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %% [markdown]
# ## Dropping Missing Values

# %%
import pandas as pd
df = pd.read_csv("car-sales-missing-data.csv", header=0)

# %%
# Making copy of the data frame
data = df.dropna()

# %%
data
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
df
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
df
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
seats = pd.Series([2, 4, 2, 5, 2, 6])

# %%
df["Seats"] = seats

# %%
df
# Out:
#      Make Colour  Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.0    4.0   $4,000    2.0
# 1   Honda    Red   87899.0    4.0   $5,000    4.0
# 2  Toyota   Blue       NaN    3.0   $7,000    2.0
# 3     BMW  Black   11179.0    5.0  $22,000    5.0
# 4  Nissan  White  213095.0    4.0   $3,500    2.0
# 5  Toyota  Green       NaN    4.0   $4,500    6.0
# 6   Honda    NaN       NaN    4.0   $7,500    NaN
# 7   Honda   Blue       NaN    4.0      NaN    NaN
# 8  Toyota  White   60000.0    NaN      NaN    NaN
# 9     NaN  White   31600.0    4.0   $9,700    NaN

# %%
df["Seats"]
# Out:
# 0    2.0
# 1    4.0
# 2    2.0
# 3    5.0
# 4    2.0
# 5    6.0
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# Name: Seats, dtype: float64

# %%
df
# Out:
#      Make Colour      Odometer  Doors    Price         Seats
# 0  Toyota  White      2.000000    4.0   $4,000      2.000000
# 1   Honda    Red      4.000000    4.0   $5,000      4.000000
# 2  Toyota   Blue      2.000000    3.0   $7,000      2.000000
# 3     BMW  Black      5.000000    5.0  $22,000      5.000000
# 4  Nissan  White      2.000000    4.0   $3,500      2.000000
# 5  Toyota  Green      6.000000    4.0   $4,500      6.000000
# 6   Honda    NaN  92302.666667    4.0   $7,500  92302.666667
# 7   Honda   Blue  92302.666667    4.0      NaN  92302.666667
# 8  Toyota  White  92302.666667    NaN      NaN  92302.666667
# 9     NaN  White  92302.666667    4.0   $9,700  92302.666667

# %%
df = pd.read_csv("car-sales-missing-data.csv", header=0)

# %%
df
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
df.loc[3]
# Out:
# Make            BMW
# Colour        Black
# Odometer    11179.0
# Doors           5.0
# Price       $22,000
# Name: 3, dtype: object

# %%
df.loc[3, "Odometer"]
# Out:
# 11179.0

# %%
df.loc[2, "Odometer"]=90000

# %%
df
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue   90000.0    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
for i in df.index:
    if df.loc[i, 'Odometer']>100000:
        df.loc[i, 'Odometer']=5000

# %%
df
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White    5000.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue   90000.0    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White    5000.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
seats = pd.Series([2, 3, 4, 2, 3, 4])

# %%
df['Seats'] = seats

# %%
df
# Out:
#      Make Colour  Odometer  Doors    Price  Seats
# 0  Toyota  White    5000.0    4.0   $4,000    2.0
# 1   Honda    Red   87899.0    4.0   $5,000    3.0
# 2  Toyota   Blue   90000.0    3.0   $7,000    4.0
# 3     BMW  Black   11179.0    5.0  $22,000    2.0
# 4  Nissan  White    5000.0    4.0   $3,500    3.0
# 5  Toyota  Green       NaN    4.0   $4,500    4.0
# 6   Honda    NaN       NaN    4.0   $7,500    NaN
# 7   Honda   Blue       NaN    4.0      NaN    NaN
# 8  Toyota  White   60000.0    NaN      NaN    NaN
# 9     NaN  White   31600.0    4.0   $9,700    NaN

# %%
df["Seats"].fillna(4, inplace=True)
# Out:
# /var/folders/tj/260lnk5505z6wf67xhl6yccw0000gn/T/ipykernel_1175/3530557960.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Seats"].fillna(4, inplace=True)

# %%
df
# Out:
#      Make Colour  Odometer  Doors    Price  Seats
# 0  Toyota  White    5000.0    4.0   $4,000    2.0
# 1   Honda    Red   87899.0    4.0   $5,000    3.0
# 2  Toyota   Blue   90000.0    3.0   $7,000    4.0
# 3     BMW  Black   11179.0    5.0  $22,000    2.0
# 4  Nissan  White    5000.0    4.0   $3,500    3.0
# 5  Toyota  Green       NaN    4.0   $4,500    4.0
# 6   Honda    NaN       NaN    4.0   $7,500    4.0
# 7   Honda   Blue       NaN    4.0      NaN    4.0
# 8  Toyota  White   60000.0    NaN      NaN    4.0
# 9     NaN  White   31600.0    4.0   $9,700    4.0

# %% [markdown]
# ## Making Column using Python List

# %%
fuelEconomy = [6.9, 8.2, 9.1, 11.4, 7.8, 8.3, 9.4, 10.3, 8.0, 9.9]

# %%
df["Fuel per 100KM"] = fuelEconomy

# %%
df
# Out:
#      Make Colour  Odometer  Doors    Price  Seats  Fuel per 100KM
# 0  Toyota  White    5000.0    4.0   $4,000    2.0             6.9
# 1   Honda    Red   87899.0    4.0   $5,000    3.0             8.2
# 2  Toyota   Blue   90000.0    3.0   $7,000    4.0             9.1
# 3     BMW  Black   11179.0    5.0  $22,000    2.0            11.4
# 4  Nissan  White    5000.0    4.0   $3,500    3.0             7.8
# 5  Toyota  Green       NaN    4.0   $4,500    4.0             8.3
# 6   Honda    NaN       NaN    4.0   $7,500    4.0             9.4
# 7   Honda   Blue       NaN    4.0      NaN    4.0            10.3
# 8  Toyota  White   60000.0    NaN      NaN    4.0             8.0
# 9     NaN  White   31600.0    4.0   $9,700    4.0             9.9

# %%
df = pd.read_csv("car-sales.csv", header=0)

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df["Seats"] = pd.Series([5, 5, 5, 5, 5])

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    NaN
# 6   Honda   Blue          45698      4   $7,500.00    NaN
# 7   Honda   Blue          54738      4   $7,000.00    NaN
# 8  Toyota  White          60000      4   $6,250.00    NaN
# 9  Nissan  White          31600      4   $9,700.00    NaN

# %%
seats = df["Seats"].fillna(5)

# %%
df["Seats"]=seats

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0
# 8  Toyota  White          60000      4   $6,250.00    5.0
# 9  Nissan  White          31600      4   $9,700.00    5.0

# %%
fuelEconomy = [7.5, 8.1, 7.0, 6.9, 7.4, 9.3, 10.3, 9.0, 10.2, 5.2]

# %%
df["Fuel per 100KM"] = fuelEconomy

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0             8.1
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             7.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             6.9
# 4  Nissan  White         213095      4   $3,500.00    5.0             7.4
# 5  Toyota  Green          99213      4   $4,500.00    5.0             9.3
# 6   Honda   Blue          45698      4   $7,500.00    5.0            10.3
# 7   Honda   Blue          54738      4   $7,000.00    5.0             9.0
# 8  Toyota  White          60000      4   $6,250.00    5.0            10.2
# 9  Nissan  White          31600      4   $9,700.00    5.0             5.2

# %%
df["Total fuel used"] = df["Odometer (KM)"]/100*df["Fuel per 100KM"]

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0             8.1
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             7.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             6.9
# 4  Nissan  White         213095      4   $3,500.00    5.0             7.4
# 5  Toyota  Green          99213      4   $4,500.00    5.0             9.3
# 6   Honda   Blue          45698      4   $7,500.00    5.0            10.3
# 7   Honda   Blue          54738      4   $7,000.00    5.0             9.0
# 8  Toyota  White          60000      4   $6,250.00    5.0            10.2
# 9  Nissan  White          31600      4   $9,700.00    5.0             5.2
#
#    Total fuel used
# 0        11253.225
# 1         7119.819
# 2         2278.430
# 3          771.351
# 4        15769.030
# 5         9226.809
# ...

# %%
df["Total fuel used"].plot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df["Colour"], df["Total fuel used"])

# %%
df["Number of wheel"] = 4

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0             8.1
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             7.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             6.9
# 4  Nissan  White         213095      4   $3,500.00    5.0             7.4
# 5  Toyota  Green          99213      4   $4,500.00    5.0             9.3
# 6   Honda   Blue          45698      4   $7,500.00    5.0            10.3
# 7   Honda   Blue          54738      4   $7,000.00    5.0             9.0
# 8  Toyota  White          60000      4   $6,250.00    5.0            10.2
# 9  Nissan  White          31600      4   $9,700.00    5.0             5.2
#
#    Total fuel used  Number of wheel
# 0        11253.225                4
# 1         7119.819                4
# 2         2278.430                4
# ...

# %%
df.drop("Total fuel used", axis=1, inplace=True)

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0             8.1
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             7.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             6.9
# 4  Nissan  White         213095      4   $3,500.00    5.0             7.4
# 5  Toyota  Green          99213      4   $4,500.00    5.0             9.3
# 6   Honda   Blue          45698      4   $7,500.00    5.0            10.3
# 7   Honda   Blue          54738      4   $7,000.00    5.0             9.0
# 8  Toyota  White          60000      4   $6,250.00    5.0            10.2
# 9  Nissan  White          31600      4   $9,700.00    5.0             5.2

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0             8.1
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             7.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             6.9
# 4  Nissan  White         213095      4   $3,500.00    5.0             7.4
# 5  Toyota  Green          99213      4   $4,500.00    5.0             9.3
# 6   Honda   Blue          45698      4   $7,500.00    5.0            10.3
# 7   Honda   Blue          54738      4   $7,000.00    5.0             9.0
# 8  Toyota  White          60000      4   $6,250.00    5.0            10.2
# 9  Nissan  White          31600      4   $9,700.00    5.0             5.2

# %%
df.sample(frac=0.5)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats  Fuel per 100KM
# 6   Honda   Blue          45698      4  $7,500.00    5.0            10.3
# 0  Toyota  White         150043      4  $4,000.00    5.0             7.5
# 9  Nissan  White          31600      4  $9,700.00    5.0             5.2
# 4  Nissan  White         213095      4  $3,500.00    5.0             7.4
# 2  Toyota   Blue          32549      3  $7,000.00    5.0             7.0

# %%
df = df.sample(frac=1)

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM
# 9  Nissan  White          31600      4   $9,700.00    5.0             5.2
# 6   Honda   Blue          45698      4   $7,500.00    5.0            10.3
# 3     BMW  Black          11179      5  $22,000.00    5.0             6.9
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 7   Honda   Blue          54738      4   $7,000.00    5.0             9.0
# 8  Toyota  White          60000      4   $6,250.00    5.0            10.2
# 5  Toyota  Green          99213      4   $4,500.00    5.0             9.3
# 1   Honda    Red          87899      4   $5,000.00    5.0             8.1
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             7.0
# 4  Nissan  White         213095      4   $3,500.00    5.0             7.4

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM
# 9  Nissan  White          31600      4   $9,700.00    5.0             5.2
# 6   Honda   Blue          45698      4   $7,500.00    5.0            10.3
# 3     BMW  Black          11179      5  $22,000.00    5.0             6.9
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 7   Honda   Blue          54738      4   $7,000.00    5.0             9.0
# 8  Toyota  White          60000      4   $6,250.00    5.0            10.2
# 5  Toyota  Green          99213      4   $4,500.00    5.0             9.3
# 1   Honda    Red          87899      4   $5,000.00    5.0             8.1
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             7.0
# 4  Nissan  White         213095      4   $3,500.00    5.0             7.4

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats  Fuel per 100KM
# 1   Honda   Blue          45698      4  $7,500.00    5.0            10.3
# 5  Toyota  White          60000      4  $6,250.00    5.0            10.2

# %%
df = pd.read_csv('car-sales.csv')

# %%
data = df.sample(frac=0.4)

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 4  Nissan  White         213095      4  $3,500.00
# 8  Toyota  White          60000      4  $6,250.00
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
data.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors      Price
# 0      4  Nissan  White         213095      4  $3,500.00
# 1      8  Toyota  White          60000      4  $6,250.00
# 2      0  Toyota  White         150043      4  $4,000.00
# 3      2  Toyota   Blue          32549      3  $7,000.00

# %%
data.reset_index(drop=True)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Nissan  White         213095      4  $3,500.00
# 1  Toyota  White          60000      4  $6,250.00
# 2  Toyota  White         150043      4  $4,000.00
# 3  Toyota   Blue          32549      3  $7,000.00

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 4  Nissan  White         213095      4  $3,500.00
# 8  Toyota  White          60000      4  $6,250.00
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
data.reset_index(drop=True, inplace=True)

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Nissan  White         213095      4  $3,500.00
# 1  Toyota  White          60000      4  $6,250.00
# 2  Toyota  White         150043      4  $4,000.00
# 3  Toyota   Blue          32549      3  $7,000.00

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df["Odometer (KM)"] = df["Odometer (KM)"].apply(lambda x:x/1.6)

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White      93776.875      4   $4,000.00
# 1   Honda    Red      54936.875      4   $5,000.00
# 2  Toyota   Blue      20343.125      3   $7,000.00
# 3     BMW  Black       6986.875      5  $22,000.00
# 4  Nissan  White     133184.375      4   $3,500.00
# 5  Toyota  Green      62008.125      4   $4,500.00
# 6   Honda   Blue      28561.250      4   $7,500.00
# 7   Honda   Blue      34211.250      4   $7,000.00
# 8  Toyota  White      37500.000      4   $6,250.00
# 9  Nissan  White      19750.000      4   $9,700.00

# %%
df = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/car-sales.csv")

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00
